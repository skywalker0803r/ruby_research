# %% [markdown]
# <a href="https://colab.research.google.com/github/skywalker0803r/ruby_research/blob/main/miner.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/sur1v/ethereum-quickstart.git
# Out:
# Cloning into 'ethereum-quickstart'...
# remote: Enumerating objects: 87, done.
# remote: Counting objects: 100% (87/87), done.
# remote: Compressing objects: 100% (47/47), done.
# remote: Total 87 (delta 39), reused 84 (delta 38), pack-reused 0
# Unpacking objects: 100% (87/87), done.

# %%
# !nvidia-smi
# Out:
# Wed Dec 30 12:07:13 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.27.04    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   33C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
import os
os.getcwd()
# Out:
# '/content'

# %%
os.chdir('/content/ethereum-quickstart')

# %%
os.getcwd()
# Out:
# '/content/ethereum-quickstart'

# %%
# !./start_ethminer.sh
# Out:
# ethminer 0.18.0
# Build: linux/release/gnu
#
#  i 12:14:55 ethminer Configured pool eth-eu1.nanopool.org:9999
#  i 12:14:55 ethminer Selected pool eth-eu1.nanopool.org:9999
#  i 12:14:55 ethminer Stratum mode : Eth-Proxy compatible
#  i 12:14:55 ethminer Established connection to eth-eu1.nanopool.org [51.15.89.69:9999]
#  i 12:14:55 ethminer Spinning up miners...
# cl 12:14:55 cl-0     Using PciId : 00:00.4 Tesla P100-PCIE-16GB (Compute 6.0) Memory : 15.90 GB
# cu 12:14:55 cuda-1   Using Pci Id : 00:04.0 Tesla P100-PCIE-16GB (Compute 6.0) Memory : 15.90 GB
#  i 12:14:55 ethminer Epoch : 385 Difficulty : 10.00 Gh
#  i 12:14:55 ethminer Job: 2387e5aa… eth-eu1.nanopool.org [51.15.89.69:9999]
# cl 12:14:58 cl-0     Generating DAG + Light : 4.07 GB
#  i 12:14:58 ethminer Job: 2387e5aa… eth-eu1.nanopool.org [51.15.89.69:9999]
# cu 12:14:58 cuda-1   Generating DAG + Light : 4.07 GB
# cl 12:14:58 cl-0     OpenCL kernel
# cl 12:14:58 cl-0     Creating light cache buffer, size: 64.12 MB
# ...
