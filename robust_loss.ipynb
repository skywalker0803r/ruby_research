# %% [markdown]
# <a href="https://colab.research.google.com/github/skywalker0803r/ruby_research/blob/main/robust_loss.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![img](https://pic2.zhimg.com/v2-6ad740980c53aa1e8154b7618338ca65_b.jpg)

# %%
import matplotlib.pyplot as plt
import numpy as np

def f(x,a,c):
  return (abs(a-2)/a)*(((x/c)**2/abs(a-2)+1)**(a/2)-1)

# %%
x = np.linspace(-6,6,1000)

# %%
for a,l in zip([-1e+64,-2.0,1e-64,0.5,1,3/2,2+1e-8],['-∞','-2','0','1/2','1','3/2','2']):
  plt.plot(x,f(x,a=a,c=1),label='a={}'.format(l))
plt.legend(loc='upper right')
plt.ylim(0,5)
plt.show()

# %%
for a,l in zip([-1e+64,-2.0,1e-64,0.5,1,3/2,2+1e-8],['-∞','-2','0','1/2','1','3/2','2']):
  plt.plot(x,f(x,a=a,c=0.5),label='a={}'.format(l))
plt.legend(loc='upper right')
plt.ylim(0,5)
plt.show()

# %%
for a,l in zip([-1e+64,-2.0,1e-64,0.5,1,3/2,2+1e-8],['-∞','-2','0','1/2','1','3/2','2']):
  plt.plot(x,f(x,a=a,c=2),label='a={}'.format(l))
plt.legend(loc='upper right')
plt.ylim(0,5)
plt.show()
